# %%
# %%html
# <style>.container {width: 98%}</style>
# Out:
# <style>.container {width: 98%}</style>

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, "../")
from fromscratch.rl.mdp import GridWorld, State, ActionSpace
from fromscratch.rl.dp import PolicyEvaluation, PolicyImprovement
from fromscratch.rl.policy import GenericPolicy

# %%
grid = GridWorld(7, 10, goal=[State([3, 7])], wind=np.array([0, 0, 0, -1, -1, -1, -2, -2, -1, 0]))
grid.set_state(State([3, 0]))

# %%
policy = GenericPolicy(grid, gamma=0.9)

# %%
grid.plot(policy)

# %%
evaluator = PolicyEvaluation(grid, policy)

# %%
for _ in range(20):
    evaluator.evaluate_once()

# %%
grid.plot(policy)

# %%
policy.reset()
improver = PolicyImprovement(grid, policy)

# %%
for _ in range(30):
    evaluator.evaluate_once()
    improver.improve_once()

# %%
grid.plot(policy)
